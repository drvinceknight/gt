# %% [markdown]
# # Normal Form Games

# %%
import nash
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
g = nash.Game([[0, 1], [1, 0]])
next(g.equilibria())
# Out:
# (array([ 0.5,  0.5]), array([ 0.5,  0.5]))

# %%
plt.plot(range(10), range(10))
