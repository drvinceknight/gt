# %% [markdown]
# ### Game Theory - 2022-2023 individual coursework
#
# **Important** Do not delete the cells containing:
#
# ```
# ### BEGIN SOLUTION
#
#
# ### END SOLUTION
# ```
#
# write your solution attempts in those cells.
#
# To submit this notebook:
#
# - Change the name of the notebook from `main` to: `<student_number>`. For example, if your student number is `c1234567` then change the name of the notebook to `c1234567`.
# - **Write all your solution attempts in the correct locations**;
# - **Do not delete** any code that is already in the cells;
# - Save the notebook (`File>Save As`);
# - Follow the instructions given to submit.

# %% [markdown]
# #### Question 1
#
# For each of the following pairs of matrices \\(A\\) and $B$, consider the [repeated game](https://nashpy.readthedocs.io/en/stable/how-to/obtain-a-repeated-game.html#how-to-obtain-a-repeated-game) obtained by repeating the game 2 times and:
#
# - create a variable `repeated_game` which has value the corresponding `nashpy` Normal Form game.
# - create a variable `row_player_strategies` which has value a generator containing the strategy space of the row player.
# - create a variable `column_player_strategies` which has value a generator containing the strategy space of the column player.
#
# a. \\(
#     A = \begin{pmatrix}1 & 2 \\ 2 & 1\end{pmatrix}
#     \qquad
#     B = \begin{pmatrix}3 & -2 \\ 1 & -5\end{pmatrix}
#     \\)
#
# _Available marks: 3_

# %%
import nashpy as nash
import nashpy.repeated_games
import numpy as np

### BEGIN SOLUTION


### END SOLUTION

# %% [markdown]
# a. \\(
#     A = \begin{pmatrix}1 & 2 \\ 2 & 1\end{pmatrix}
#     \qquad
#     B = - A
#     \\)
#
# _Available marks: 3_

# %%
### BEGIN SOLUTION


### END SOLUTION

# %% [markdown]
# c. \\(
#     A = \begin{pmatrix}1 & 2 & 3 \\ 2 & 1 & 4\end{pmatrix}
#     \qquad
#     B = A
#     \\)
#
# _Available marks: 3_

# %%
### BEGIN SOLUTION


### END SOLUTION

# %% [markdown]
# ### Question 2
#
#
# a. Consider the [replicator dynamics](https://nashpy.readthedocs.io/en/stable/how-to/use-replicator-dynamics.html) on the population described by the following matrix:
#
#    \\(A = \begin{pmatrix}4 & 2 & 5 & 1\\ 6 & 1 & 4 & 2 \\ 8 & 2 & 1 & 3\\ 2 & 3 & 1 & 3\end{pmatrix}\\)
#
#    Given an initial population vector: \\(x=(1/4, 1/4, 1/4, 1/4)\\) create a variable `base_population` (as a numpy array) which has value the population vector after 500 timepoints (as given by the given variable `timepoints`).
#
# _Available marks: 4_

# %%
timepoints = np.linspace(0, 1, 500)
### BEGIN SOLUTION


### END SOLUTION

# %% [markdown]
# b. Consider that after these 500 timepoints mutation starts to happen within the population. Individuals of the first, second and third type can mutate to become individuals of the fourth type (and only the fourth type) with probability: 1/5.
#
# Create a variable `mutation_matrix` that has value the matrix representing this mutation for the [mutation-replicator dynamics equation](https://nashpy.readthedocs.io/en/stable/text-book/replicator-dynamics.html#the-replicator-mutation-dynamics-equation).
#
#
# _Available marks: 2_

# %%
### BEGIN SOLUTION


### END SOLUTION

# %% [markdown]
# c. Output the final population (of the last timepoint) obtained by using `base_population` (from question 2-a) as an initial population for the [mutation-replicator dynamics equation](https://nashpy.readthedocs.io/en/stable/text-book/replicator-dynamics.html#the-replicator-mutation-dynamics-equation) for a further 500 timepoints.
#
# _Available marks: 4_

# %%
### BEGIN SOLUTION


### END SOLUTION

# %% [markdown]
# ### Question 3
#
# Consider the following game defined by parameters $\alpha, \beta$:
#
# $$
# A = \begin{pmatrix}
#         5 & \alpha & 2\\
#         4 & \beta & 3\\
#         1 & \alpha + \beta & 1\\
#     \end{pmatrix}
#     \qquad
# B = \begin{pmatrix}
#         \alpha & 3 & 2\\
#         \beta & 2 & 3\\
#         2 & 3& \beta\\
#     \end{pmatrix}
# $$
#
# a. Create a pair of variables `alpha_that_gives_1_equilibria` and `beta_that_gives_1_equilibria` that have value, the values of $\alpha$ and $\beta$ for which the [support enumeration](https://nashpy.readthedocs.io/en/stable/how-to/solve-with-support-enumeration.html#how-to-use-support-enumeration) algorithm gives a single Nash equilibria.
#
# _Available marks: 3_

# %%
### BEGIN SOLUTION


### END SOLUTION

# %% [markdown]
# b. Create a pair of variables `alpha_that_gives_3_equilibria` and `beta_that_gives_3_equilibria` that have value, the values of $\alpha$ and $\beta$ for which the [support enumeration](https://nashpy.readthedocs.io/en/stable/how-to/solve-with-support-enumeration.html#how-to-use-support-enumeration) algorithm gives exactly 3 Nash equilibria.
#
# _Available marks: 3_

# %%
### BEGIN SOLUTION


### END SOLUTION

# %% [markdown]
# c. Create a pair of variables `alpha_that_gives_5_equilibria` and `beta_that_gives_5_equilibria` that have value, the values of $\alpha$ and $\beta$ for which the [support enumeration](https://nashpy.readthedocs.io/en/stable/how-to/solve-with-support-enumeration.html#how-to-use-support-enumeration) algorithm gives exactly 5 Nash equilibria.
#
# _Available marks: 3_

# %%
### BEGIN SOLUTION


### END SOLUTION

# %% [markdown]
# ### Question 4
#
# For game defined by:
#
# $$
# A = \begin{pmatrix}0 & 3 & 1\\ 1 & 2 & 0\end{pmatrix}
# \qquad
# B = \begin{pmatrix}2 & 1 & 0\\ 0 & 2 & 1\end{pmatrix}
# $$
#
#
# a. Create a variable `equilibria` which has value the Nash equilibria of the game as a list using support enumeration.
#
# _Available marks: 2_

# %%
A = np.array([[0, 3, 1], [1, 2, 0]])
B = np.array([[2, 1, 0], [0, 2, 1]])
### BEGIN SOLUTION


### END SOLUTION

# %% [markdown]
# b. Use [asymmetric replicator dynamics](https://nashpy.readthedocs.io/en/stable/text-book/asymmetric-replicator-dynamics.html) to create two variables `xs` and `ys` which have value the strategies over time for the given initial populations `x0` and `y0` and timepoints `timepoints`.
#
# _Available marks: 4_

# %%
x0 = np.array([2 / 3, 1 / 3])
y0 = np.array([1 / 2, 1 / 2, 0])
timepoints = np.linspace(0, 10, 1000)
### BEGIN SOLUTION


### END SOLUTION
