# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data/main.csv")
df['Group Coursework [Total Pts: 100 Score] |932379'].describe().round(3)
# Out:
# count    101.000
# mean      70.465
# std        7.076
# min       54.000
# 25%       66.000
# 50%       70.000
# 75%       75.000
# max       84.000
# Name: Group Coursework [Total Pts: 100 Score] |932379, dtype: float64

# %%
plt.figure()
plt.hist(df['Group Coursework [Total Pts: 100 Score] |932379'], bins=20)
plt.xlim(0, 100)
plt.title("Group coursework mark distribution")
plt.ylabel("Frequency")
plt.xlabel("Mark")
plt.savefig("main.png", dpi=300);
