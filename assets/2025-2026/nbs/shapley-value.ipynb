# %% [markdown]
# The blue game:

# %%
import coopgt.shapley_value


characteristic_function = {
    (): 0,
    (1,): 0,
    (2,): 4,
    (3,): 2,
    (1, 2): 4,
    (2, 3): 6,
    (1, 3): 2,
    (1, 2, 3): 6,
}
coopgt.shapley_value.calculate(characteristic_function=characteristic_function)
# Out:
# array([0., 4., 2.])

# %% [markdown]
# The red game:

# %%
characteristic_function = {
    (): 0,
    (1,): 2,
    (2,): 3,
    (3,): 1,
    (1, 2): 4,
    (2, 3): 4,
    (1, 3): 3,
    (1, 2, 3): 6,
}
coopgt.shapley_value.calculate(characteristic_function=characteristic_function)
# Out:
# array([1.83333333, 2.83333333, 1.33333333])

# %% [markdown]
# A slightly modified version of the game:

# %%
characteristic_function = {
    (): 0,
    (1,): 2,
    (2,): 3,
    (3,): 1,
    (1, 2): 5,
    (2, 3): 4,
    (1, 3): 3,
    (1, 2, 3): 6,
}
coopgt.shapley_value.calculate(characteristic_function=characteristic_function)
# Out:
# array([2., 3., 1.])
